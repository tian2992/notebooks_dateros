# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

plt.rcParams['figure.figsize'] = 8, 5
plt.style.use("fivethirtyeight")

# %%
p_df = pd.read_csv("Birthweight_reduced_kg_.csv")
p_df.head()
# Out:
#      ID  Length  Birthweight  Headcirc  Gestation  smoker  mage  mnocig  \
# 0  1360      56         4.55        34         44       0    20       0
# 1  1016      53         4.32        36         40       0    19       0
# 2   462      58         4.10        39         41       0    35       0
# 3  1187      53         4.07        38         44       0    20       0
# 4   553      54         3.94        37         42       0    24       0
#
#    mheight  mppwt  fage  fedyrs  fnocig  fheight  lowbwt  mage35
# 0      162     57    23      10      35      179       0       0
# 1      171     62    19      12       0      183       0       0
# 2      172     58    31      16      25      185       0       1
# 3      174     68    26      14      25      189       0       0
# 4      175     66    30      12       0      184       0       0

# %%
p_df.corr()
# Out:
#                    ID    Length  Birthweight  Headcirc  Gestation  \
# ID           1.000000  0.192635     0.111211 -0.044899   0.102714
# Length       0.192635  1.000000     0.726833  0.563172   0.705111
# Birthweight  0.111211  0.726833     1.000000  0.684616   0.708303
# Headcirc    -0.044899  0.563172     0.684616  1.000000   0.404635
# Gestation    0.102714  0.705111     0.708303  0.404635   1.000000
# smoker      -0.276182 -0.153406    -0.314234 -0.182872  -0.094746
# mage        -0.186426  0.075268     0.000173  0.145842   0.010778
# mnocig      -0.194625 -0.039843    -0.152335 -0.132988   0.043195
# mheight     -0.010893  0.484992     0.363055  0.337047   0.210503
# mppwt       -0.026516  0.398197     0.400886  0.302854   0.255082
# fage        -0.231958  0.137184     0.175710  0.301151   0.142175
# fedyrs       0.119927  0.079485     0.071045  0.123892   0.130987
# fnocig      -0.112889  0.008800    -0.093136 -0.046837  -0.113831
# ...

# %%
plt.figure(figsize=(12,12))
sns.heatmap(p_df.corr(), cmap="YlGnBu", annot=True,)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data=p_df, hue="mnocig", size=3, diag_kind="hist")
# Out:
# /home/tian/miniconda3/envs/scientificProject/lib/python3.9/site-packages/seaborn/axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
cols_para_peso = ["Length", "Birthweight", "Gestation", "mage", "mnocig", "mppwt"]

# %%
sns.pairplot(data=p_df[cols_para_peso], hue="Gestation", size=3, diag_kind="hist")
# Out:
# /home/tian/miniconda3/envs/scientificProject/lib/python3.9/site-packages/seaborn/axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(data=p_df[["Birthweight","smoker", "mnocig", "fnocig"]], hue="smoker", size=3, diag_kind="hist")
# Out:
# /home/tian/miniconda3/envs/scientificProject/lib/python3.9/site-packages/seaborn/axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(data=p_df[["Length","Birthweight","mheight", "mage"]], hue="mage", size=3, diag_kind="hist")
# Out:
# /home/tian/miniconda3/envs/scientificProject/lib/python3.9/site-packages/seaborn/axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# p_df["nueva_col"] = p_df.query(p_df.mage>20)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

target_vars = ["Length"]
source_vars = ["Birthweight", "mheight"]

X = p_df[source_vars]
y = p_df[target_vars]

X_train, X_test, y_train, y_test = train_test_split(X,y)

model = LinearRegression().fit(X_train, y_train)

# %%
model.score(X_test, y_test)
#print(f"Efectivadad del modelo contra el dataset de prueba {}")
# Out:
# -0.5276201472120825
